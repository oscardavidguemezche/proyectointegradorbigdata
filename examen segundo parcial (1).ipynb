# %% [markdown]
# # examen Guemez Che Oscar David

# %% [markdown]
# # Libreria

# %%
import pandas as pd
import seaborn as sns



from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importacion de los datos

# %%
datos = pd.read_csv("data.csv")

# %% [markdown]
# # 10 Artistas ordenados alfabeticamente

# %%
by_artist = datos.sort_values('artists', ascending=True)
by_artist.head(10)
# Out:
#         acousticness                                            artists  \
# 107980       0.84800  ["'In The Heights' Original Broadway Company",...
# 87166        0.06060                                   ["'Til Tuesday"]
# 12910        0.02820                                   ["'Til Tuesday"]
# 151863       0.09890                                   ["'Til Tuesday"]
# 151760       0.20700                                   ["'Til Tuesday"]
# 86093        0.00336                                   ["'Til Tuesday"]
# 32430        0.00339                                   ["'Til Tuesday"]
# 167074       0.26200                                   ["'Til Tuesday"]
# 51574        0.18100                                   ["'Til Tuesday"]
# 166405       0.68200                  ["100 First Songs' Participants"]
#
#         danceability  duration_ms  energy  explicit                      id  \
# 107980         0.397       244067   0.242         0  6OSTrvIX8JXxRxFT4C9y0J
# ...

# %% [markdown]
# # Datos que se pueden relacionar
# relacion 1 = artists, danceability, duration_ms ,energy
# relacion 2 = artists, instrumentalness	, liveness, loudness
# relacion 3 = artists, name, popularity, release_date

# %%
relation1 = datos[['artists','danceability','duration_ms','energy']]
relation2 = datos[['artists','instrumentalness','liveness','loudness']]
relation3 = datos[['artists','name','popularity','release_date']]

# %%
relation1.head(10)
# Out:
#                              artists  danceability  duration_ms  energy
# 0                    ['Mamie Smith']         0.598       168333  0.2240
# 1          ["Screamin' Jay Hawkins"]         0.852       150200  0.5170
# 2                    ['Mamie Smith']         0.647       163827  0.1860
# 3                ['Oscar Velazquez']         0.730       422087  0.7980
# 4                           ['Mixe']         0.704       165224  0.7070
# 5  ['Mamie Smith & Her Jazz Hounds']         0.424       198627  0.2450
# 6                    ['Mamie Smith']         0.782       195200  0.0573
# 7  ['Mamie Smith & Her Jazz Hounds']         0.474       186173  0.2390
# 8               ['Francisco Canaro']         0.469       146840  0.2380
# 9                         ['Meetya']         0.571       476304  0.7530

# %%
relation2.head(10)
# Out:
#                              artists  instrumentalness  liveness  loudness
# 0                    ['Mamie Smith']          0.000522    0.3790   -12.628
# 1          ["Screamin' Jay Hawkins"]          0.026400    0.0809    -7.261
# 2                    ['Mamie Smith']          0.000018    0.5190   -12.098
# 3                ['Oscar Velazquez']          0.801000    0.1280    -7.311
# 4                           ['Mixe']          0.000246    0.4020    -6.036
# 5  ['Mamie Smith & Her Jazz Hounds']          0.799000    0.2350   -11.470
# 6                    ['Mamie Smith']          0.000002    0.1760   -12.453
# 7  ['Mamie Smith & Her Jazz Hounds']          0.186000    0.1950    -9.712
# 8               ['Francisco Canaro']          0.960000    0.1490   -18.717
# 9                         ['Meetya']          0.873000    0.0920    -6.943

# %%
relation3.head(10)
# Out:
#                              artists  \
# 0                    ['Mamie Smith']
# 1          ["Screamin' Jay Hawkins"]
# 2                    ['Mamie Smith']
# 3                ['Oscar Velazquez']
# 4                           ['Mixe']
# 5  ['Mamie Smith & Her Jazz Hounds']
# 6                    ['Mamie Smith']
# 7  ['Mamie Smith & Her Jazz Hounds']
# 8               ['Francisco Canaro']
# 9                         ['Meetya']
#
#                                                 name  popularity release_date
# 0                           Keep A Song In Your Soul          12         1920
# 1                               I Put A Spell On You           7   1920-01-05
# 2                                       Golfing Papa           4         1920
# 3  True House Music - Xavier Santos & Carlos Gomi...          17   1920-01-01
# 4                                          Xuniverxe           2   1920-10-01
# 5                        Crazy Blues - 78rpm Version           9         1920
# ...

# %% [markdown]
# # comando describe

# %%
datos.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  174389.000000  174389.000000  1.743890e+05  174389.000000
# mean        0.499228       0.536758  2.328100e+05       0.482721
# std         0.379936       0.176025  1.483958e+05       0.272685
# min         0.000000       0.000000  4.937000e+03       0.000000
# 25%         0.087700       0.414000  1.661330e+05       0.249000
# 50%         0.517000       0.548000  2.057870e+05       0.465000
# 75%         0.895000       0.669000  2.657200e+05       0.711000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  174389.000000     174389.000000  174389.000000  174389.000000
# mean        0.068135          0.197252       5.205305       0.211123
# std         0.251978          0.334574       3.518292       0.180493
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # promedio

# %%
datos.mean()

# %% [markdown]
# # Mediana

# %%
datos.median()
# Out:
# acousticness             0.517000
# danceability             0.548000
# duration_ms         205787.000000
# energy                   0.465000
# explicit                 0.000000
# instrumentalness         0.000524
# key                      5.000000
# liveness                 0.138000
# loudness               -10.836000
# mode                     1.000000
# popularity              25.000000
# speechiness              0.045500
# tempo                  115.816000
# valence                  0.536000
# year                  1977.000000
# dtype: float64

# %% [markdown]
# # varianza

# %%
datos.var(ddof=0)
# Out:
# acousticness        1.443504e-01
# danceability        3.098471e-02
# duration_ms         2.202119e+10
# energy              7.435694e-02
# explicit            6.349265e-02
# instrumentalness    1.119389e-01
# key                 1.237831e+01
# liveness            3.257743e-02
# loudness            3.239402e+01
# mode                2.090408e-01
# popularity          4.784140e+02
# speechiness         3.321858e-02
# tempo               9.153100e+02
# valence             6.994758e-02
# year                7.240336e+02
# dtype: float64

# %% [markdown]
# # minimos y maximos

# %%
datos.max()
# Out:
# acousticness                         0.996
# artists                            ['조정현']
# danceability                         0.988
# duration_ms                        5338302
# energy                                   1
# explicit                                 1
# id                  7zzuPsjj9L3M7ikqGmjN0D
# instrumentalness                         1
# key                                     11
# liveness                                 1
# loudness                             3.855
# mode                                     1
# name                    텅 빈 마음 Empty Heart
# popularity                             100
# release_date                    2021-01-23
# speechiness                          0.971
# tempo                              243.507
# valence                                  1
# year                                  2021
# dtype: object

# %%
datos.min()
# Out:
# acousticness                                                        0
# artists             ["'In The Heights' Original Broadway Company",...
# danceability                                                        0
# duration_ms                                                      4937
# energy                                                              0
# explicit                                                            0
# id                                             000G1xMMuwxNHmwVsBdtj1
# instrumentalness                                                    0
# key                                                                 0
# liveness                                                            0
# loudness                                                          -60
# mode                                                                0
# name                                                             "40"
# ...

# %% [markdown]
# # ¿cuales valores pueden tener una relacion lineal positiva, demuestre y diga porque lo considera asi?

# %%
sns.pairplot(relation1, kind='reg')
plt.show()

# %%
sns.pairplot(relation2, kind='reg')
plt.show()

# %%
sns.pairplot(relation3, kind='reg')
plt.show()

# %% [markdown]
# # considero que la relacion 1 es la que tendria una relacion positiva con la musica, y la energia ademas de la duracion para llevar un control
