# %%
# Examen unidad 2

# %%
### importar librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
### importamos datos

# %%
df = pd.read_csv("data.csv")

# %%
## Obtener los primero 10 artistas en orden alfabetico

a = df['artists'].head(10)
a.sort_values(ascending = True)
# Out:
# 1            ["Screamin' Jay Hawkins"]
# 8                 ['Francisco Canaro']
# 5    ['Mamie Smith & Her Jazz Hounds']
# 7    ['Mamie Smith & Her Jazz Hounds']
# 0                      ['Mamie Smith']
# 2                      ['Mamie Smith']
# 6                      ['Mamie Smith']
# 9                           ['Meetya']
# 4                             ['Mixe']
# 3                  ['Oscar Velazquez']
# Name: artists, dtype: object

# %%
## Relacionar datos

relacion = df[['artists','danceability','energy','explicit']]
relacion
# Out:
#                                    artists  danceability  energy  explicit
# 0                          ['Mamie Smith']         0.598   0.224         0
# 1                ["Screamin' Jay Hawkins"]         0.852   0.517         0
# 2                          ['Mamie Smith']         0.647   0.186         0
# 3                      ['Oscar Velazquez']         0.730   0.798         0
# 4                                 ['Mixe']         0.704   0.707         1
# ...                                    ...           ...     ...       ...
# 174384  ['DJ Combo', 'Sander-7', 'Tony T']         0.792   0.866         0
# 174385                    ['Alessia Cara']         0.429   0.211         0
# 174386                       ['Roger Fly']         0.671   0.589         0
# 174387                    ['Taylor Swift']         0.462   0.240         1
# 174388                       ['Roger Fly']         0.677   0.460         0
#
# [174389 rows x 4 columns]

# %%
## Identificar datos

### Mediana
mediana = df["danceability"].median()

### Promedio
media = df["danceability"].mean()

### Varianza
varianza = df["danceability"].var(ddof=0)

### Minimo
minimo = df["danceability"].min()

### Maximo
maximo = df["danceability"].max()

# %%
## Relacion lineal positiva

correlacion = df.corr(method='spearman')
correlacion
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.228375    -0.224872 -0.761150 -0.196704
# danceability         -0.228375      1.000000    -0.063275  0.200086  0.203177
# duration_ms          -0.224872     -0.063275     1.000000  0.178390 -0.033255
# energy               -0.761150      0.200086     0.178390  1.000000  0.101960
# explicit             -0.196704      0.203177    -0.033255  0.101960  1.000000
# instrumentalness      0.194350     -0.238385     0.136720 -0.131763 -0.203598
# key                  -0.026626      0.024832     0.004175  0.035079  0.005025
# liveness              0.011428     -0.129079    -0.088626  0.072922  0.053050
# loudness             -0.585290      0.203365     0.136663  0.812983  0.126325
# mode                  0.061574     -0.049432    -0.071148 -0.055022 -0.062503
# popularity           -0.397944      0.100034     0.184780  0.339710  0.122644
# ...

# %%
sns.heatmap(correlacion, xticklabels = correlacion.columns, yticklabels = correlacion.columns, cmap='coolwarm')

# %%
### Como podemos observar en el grafico, hay ciertos patrones de relacion entre las columnas por ejemplo:
 ### La columna energia esta bastante relacionado con el ruido, lo cual nos indica que entre mas ruidosa sea la cancion mas energica es.
 ### Caso contrario con energia y acustica, en donde podemos observar un claro contraste ya que no presenta mucha relacion
